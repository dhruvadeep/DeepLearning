# %% [markdown]
# Calculus

# %%
# %matplotlib inline
import numpy as np
from matplotlib_inline import backend_inline

# %%
from required import torch as d2l

# %%
import math

# %%
def f(x):
    return 3 * x ** 2 - 4 * x

# %%
for h in 10.0**np.arange(-1, -6, -1):
    print(f'h={h:.5f}, numerical limit={(f(1+h)-f(1))/h:.5f}')
# Out:
# h=0.10000, numerical limit=2.30000
# h=0.01000, numerical limit=2.03000
# h=0.00100, numerical limit=2.00300
# h=0.00010, numerical limit=2.00030
# h=0.00001, numerical limit=2.00003

# %%
def f(x):
    return 3 * x ** 2 - 4 * x

# %%
for h in 10.0**np.arange(-1, -6, -1):
    print(f'h={h:.5f}, numerical limit={(f(1+h)-f(1-h))/(2*h):.5f}')
# Out:
# h=0.10000, numerical limit=2.00000
# h=0.01000, numerical limit=2.00000
# h=0.00100, numerical limit=2.00000
# h=0.00010, numerical limit=2.00000
# h=0.00001, numerical limit=2.00000

# %%
def use_svg_display():  #@save
    """Use the svg format to display a plot in Jupyter."""
    backend_inline.set_matplotlib_formats('svg')

def set_figsize(figsize=(3.5, 2.5)):  #@save
    """Set the figure size for matplotlib."""
    use_svg_display()
    d2l.plt.rcParams['figure.figsize'] = figsize

#@save
def set_axes(axes, xlabel, ylabel, xlim, ylim, xscale, yscale, legend):
    """Set the axes for matplotlib."""
    axes.set_xlabel(xlabel), axes.set_ylabel(ylabel)
    axes.set_xscale(xscale), axes.set_yscale(yscale)
    axes.set_xlim(xlim),     axes.set_ylim(ylim)
    if legend:
        axes.legend(legend)
    axes.grid()

#@save
def plot(X, Y=None, xlabel=None, ylabel=None, legend=[], xlim=None,
         ylim=None, xscale='linear', yscale='linear',
         fmts=('-', 'm--', 'g-.', 'r:'), figsize=(3.5, 2.5), axes=None):
    """Plot data points."""

    def has_one_axis(X):  # True if X (tensor or list) has 1 axis
        return (hasattr(X, "ndim") and X.ndim == 1 or isinstance(X, list)
                and not hasattr(X[0], "__len__"))

    if has_one_axis(X): X = [X]
    if Y is None:
        X, Y = [[]] * len(X), X
    elif has_one_axis(Y):
        Y = [Y]
    if len(X) != len(Y):
        X = X * len(Y)

    set_figsize(figsize)
    if axes is None:
        axes = d2l.plt.gca()
    axes.cla()
    for x, y, fmt in zip(X, Y, fmts):
        axes.plot(x,y,fmt) if len(x) else axes.plot(y,fmt)
    set_axes(axes, xlabel, ylabel, xlim, ylim, xscale, yscale, legend)

# %%
x = np.arange(0, 3, 0.1)
plot(x, [f(x), 2*x-3], 'x', 'f(x)', legend=['f(x)', 'Tangent line (x=1)'])

# %% [markdown]
# Exercise

# %%
# Defination and limit to prove thse 
# 1. f(x) = c
def f(x):
    return 1 # const

for h in 10.0**np.arange(-1, -6, -1):
    print(f'h={h:.5f}, numerical limit={(f(1+h)-f(1))/h:.5f}')
# Out:
# h=0.10000, numerical limit=0.00000
# h=0.01000, numerical limit=0.00000
# h=0.00100, numerical limit=0.00000
# h=0.00010, numerical limit=0.00000
# h=0.00001, numerical limit=0.00000

# %%
# Defination and limit to prove thse 
# 1. f(x) = x^n
def f(x):
    return x**3 # const

# limit at h=0 and x=1
for h in 10.0**np.arange(-1, -6, -1):
    print(f'h={h:.5f}, numerical limit={(f(1+h)-f(1))/h:.5f}')
# Out:
# h=0.10000, numerical limit=3.31000
# h=0.01000, numerical limit=3.03010
# h=0.00100, numerical limit=3.00300
# h=0.00010, numerical limit=3.00030
# h=0.00001, numerical limit=3.00003

# %%
# Defination and limit to prove thse 
# 1. f(x) = x^n
def f(x):
    return math.exp(x)


# limit at h=0 and x=1
for h in 10.0**np.arange(-1, -6, -1):
    print(f'h={h:.5f}, numerical limit={(f(1+h)-f(1))/h:.5f}, Actual limit={math.exp(1):.5f}')
# Out:
# h=0.10000, numerical limit=2.85884, Actual limit=2.71828
# h=0.01000, numerical limit=2.73192, Actual limit=2.71828
# h=0.00100, numerical limit=2.71964, Actual limit=2.71828
# h=0.00010, numerical limit=2.71842, Actual limit=2.71828
# h=0.00001, numerical limit=2.71830, Actual limit=2.71828

# %%
# Defination and limit to prove thse 
# 1. f(x) = x^n
def f(x):
    return math.log(x)


# limit at h=0 and x=1
for h in 10.0**np.arange(-1, -6, -1):
    print(f'h={h:.5f}, numerical limit={(f(1+h)-f(1))/h:.5f}, Actual limit={1/1:.5f}')
# Out:
# h=0.10000, numerical limit=0.95310, Actual limit=1.00000
# h=0.01000, numerical limit=0.99503, Actual limit=1.00000
# h=0.00100, numerical limit=0.99950, Actual limit=1.00000
# h=0.00010, numerical limit=0.99995, Actual limit=1.00000
# h=0.00001, numerical limit=1.00000, Actual limit=1.00000

# %%
# In the same vien prove the product, sum, and quotient rules from first limit principles

# %%
'''
What does it mean that 
 for some f'x = 0
? Give an example of a function 
 and a location 
 for which this might hold
'''
def f(x):
    return x**2 - 4*x + 4

def x_0(x):
    return 0 + 0*x

# Derivative of f(x) = 2x - 4
# f'x = 0 when x = 2

# Ploting the graph
np.arange(0, 5, 0.1)
plot(x, [f(x), x_0(x)], 'x', 'f(X)', legend=['f(x)', 'x=0'])

# %%
# Plot function y = x^3 - 1/x and its tangent line at x = 1
def f(x):
    return x**3 - 1/x

# According to the power rule and multiple rule," 3 * x ** 2 + 1 / (x ** 2) "is the derivative function of f (x).
# So x == 1,f’(1) ==3 * 1 **2 + 1 / (1 ** 2) == 3 + 1 == 4,tangent line’s slope is 4.
# and for intercept ie. c in y = mx + c, we can use the point (1, f(1)) = (1, 1) to solve for c.

x = np.arange(0.1, 3, 0.1)
plot(x, [f(x), 4*x-4], 'x', 'f(x)', legend=['f(x)', 'Tangent line (x=1)'])

# %%
# Find the gradient of function f(x) = 3x_1^2 + 5e^x_2
# f(x) = 3x_1^2 + 5e^x_2
# gradient of f(x) = [6x_1, 5e^x_2]

# plot the function its 3d
def f(x1, x2):
    return 3 * x1 ** 2 + 5 * np.exp(x2)

def f_grad(x1, x2):
    return (6 * x1, 5 * np.exp(x2))

from matplotlib import cm
from matplotlib.pyplot import figure 
import matplotlib.pyplot as plt
import math

figure(figsize=(8, 6), dpi=80)
fig, ax = plt.subplots(subplot_kw={'projection': '3d'})
x1 = np.arange(-5, 5, 0.1)
x2 = np.arange(-5, 5, 0.1)

X, Y = np.meshgrid(x1, x2)
R = f(X, Y)
surf = ax.plot_surface(X, Y, R, cmap=cm.coolwarm)
